# %% [markdown]
# <a href="https://colab.research.google.com/github/MUjeebAQ/CV-/blob/main/Tip_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to the tip calculator!")
Bill = float(input("What was the total bill? Rs"))
Tip = int(input("What percentage tip would you like to give? 10,12,15:"))
People = int(input("How many people to split the bill?"))
tip_as_percent= Tip/100
total_tip_amount= Bill*tip_as_percent
total_bill= Bill + total_tip_amount
bill_per_person = total_bill/People
final_amount= round(bill_per_person,2)
print(f"Each person should pay:Rs{final_amount}")
# Out:
# Welcome to the tip calculator!
# What was the total bill? Rs10000
# What percentage tip would you like to give? 10,12,15:15
# How many people to split the bill?5
# Each person should pay:Rs2300.0
